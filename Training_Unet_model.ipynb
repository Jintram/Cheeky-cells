# %% [markdown]
# # Training a U-net model

# %% [markdown]
# I trained a U-net to recognize fluorescent images.
#
# - The whole training was done in the file:
#     - `mypytorch_fullseg/testing_code_fullseg.py`.
# - The image were pre-processed in the file:
#     - `source/annotation_aided.py`
# - Rest of the U-net code can be found in folder:
#     - `mypytorch_fullseg`
