# %%
# %gui qt

import sys
sys.path.append('/Users/m.wehrens/Documents/git_repos/_UVA/2025_Cheeky-cells/')

import source.preprocessing as cheepre

# %%
import importlib; importlib.reload(cheepre)
# Out:
# <module 'source.preprocessing' from '/Users/m.wehrens/Documents/git_repos/_UVA/2025_Cheeky-cells/source/preprocessing.py'>

# %%
# create grey scale images 
IMG_DIRECTORY='/Users/m.wehrens/Data_UVA/2024_07_Wang-cel/2025_Cells_preliminarybatch1/Cheeck-Cells_AnnotatedMW_resized/'
cheepre.convert_imgs_togrey(IMG_DIRECTORY)

# %% [markdown]
# ### Current segmentation labels
#
# - 1 = background
# - 2 = cell outline
# - 3 = cell outline between cells
# - 4 = cell cytoplasm
# - 5 = nuclei

# %%
from napari.settings import SETTINGS
SETTINGS.application.ipy_interactive = False

IMG_DIRECTORY='/Users/m.wehrens/Data_UVA/2024_07_Wang-cel/2025_Cells_preliminarybatch1/Cheeck-Cells_AnnotatedMW_resized/'
cheepre.annotate_pictures(input_folder=IMG_DIRECTORY, output_folder=None)
# Out:
# WARNING: Could not find virtual screen for QCocoaScreen(0x3f83373a0, "DELL U2311H", QRect(-1920,-412 1920x1080), dpr=1, displayId=151, <NSScreen: 0x36086fe90>) with displayId 151
# Skipping to next image
# WARNING: Could not find virtual screen for QCocoaScreen(0x3f83373a0, "DELL U2311H", QRect(-1920,-412 1920x1080), dpr=1, displayId=151, <NSScreen: 0x36086fe90>) with displayId 151
# WARNING: Could not find virtual screen for QCocoaScreen(0x3f83373a0, "DELL U2311H", QRect(-1920,-412 1920x1080), dpr=1, displayId=151, <NSScreen: 0x36086fe90>) with displayId 151
# Skipping to next image
# WARNING: Could not find virtual screen for QCocoaScreen(0x3f83373a0, "DELL U2311H", QRect(-1920,-412 1920x1080), dpr=1, displayId=151, <NSScreen: 0x36086fe90>) with displayId 151
# WARNING: Could not find virtual screen for QCocoaScreen(0x3f83373a0, "DELL U2311H", QRect(-1920,-412 1920x1080), dpr=1, displayId=151, <NSScreen: 0x36086fe90>) with displayId 151
# Skipping to next image
# ...
